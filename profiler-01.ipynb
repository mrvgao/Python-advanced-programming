# %% [markdown]
# ## Profiler

# %% [markdown]
# 如果一件事情无法量化，则很难优化。

# %% [markdown]
# 如何我们想优化程序，提升速度，那么，我们要学习的第一件事情就是如何观察程序的运行效率。 不仅仅指的是运行时间：
#
# 1. 调用过程中的时间花费；
# 2. 每行语句的时间花费；
# 3. 内存消耗；

# %% [markdown]
# 1. JupyterNotebook
# 2. Python脚本
# 3. 集成化的IDE

# %% [markdown]
# ## Jupyter Notebook

# %% [markdown]
# 1.  最简单的工具：  %tiimeit "stmt": 进行一定的iterations 看出时间 stmt 运行的时间
# 2.
#  %%time
#
#  block

# %% [markdown]
# Jupyter里边的profiler工具： prun

# %%
def complex_coef(n, i): 
    return [j ^ (j >> i) for j in range(n)]

def sum_of_lists(N):
    total = 0
    for i in range(N):        
        L = complex_coef(N, i)
        total += sum(L)
    return total

# %%
# %prun sum_of_lists(10000)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1971年的时候，Don Knuth's 高纳德. 如果一个程序，是非IO密集型的，发现运行缓慢，低于17%行数的代码，会消耗80%以上的时间。

# %% [markdown]
# ## 行数工具

# %%
# !pip install line_profiler
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...
#     100% |████████████████████████████████| 61kB 2.5MB/s ta 0:00:011
# ...

# %%
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# %lprun -f sum_of_lists sum_of_lists(100)

# %% [markdown]
# ## 素数的案例

# %% [markdown]
# 找到小于等于N的所有的素数

# %%
import numpy as np

# %%
def root(n): 
    return int(np.sqrt(n))

# %%
def prime(n):
    
#    for i in range(2, root(n)): 
    if any(n % i == 0 for i in (2, 3, 5, 7)):
        return True
    else:
        #print()
        root_n = int(n ** 0.5)
        for i in range(11, root_n, 2): 
            #print(i, end=', ')
            if n % i == 0: 
                return False
        return True

# %%
def collect(n):
    collected = []
    
    for i in range(2, n+1): 
        if prime(i):
            collected.append(i)
            
    return collected

# %%
r = collect(20000)
# Out:
# 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 5, 3, 3, 5, 3, 5, 3, 3, 5, 3, 5, 3, 3, 5, 3, 5, 3, 3, 5, 3, 5, 3, 3, 5, 3, 5, 7, 3, 3, 5, 7, 3, 5, 7, 3, 3, 5, 7, 3, 5, 7, 3, 3, 5, 7, 3, 5, 3, 3, 5, 7, 3, 5, 7, 3, 3, 5, 3, 5, 7, 3, 3, 5, 7, 9, 3, 5, 7, 9, 3, 3, 5, 7, 9, 3, 5, 7, 9, 3, 3, 5, 7, 9, 3, 5, 3, 3, 5, 7, 3, 5, 7, 9, 3, 3, 5, 3, 5, 7, 9, 3, 3, 5, 7, 9, 3, 5, 7, 3, 3, 5, 7, 9, 3, 5, 7, 9, 3, 3, 5, 7, 9, 3, 5, 3, 3, 5, 7, 9, 11, 3, 5, 7, 9, 11, 3, 3, 5, 3, 5, 7, 9, 11, 3, 3, 5, 7, 3, 5, 7, 9, 11, 3, 3, 5, 7, 9, 11, 3, 5, 7, 9, 11, 3, 3, 5, 7, 9, 11, 3, 5, 3, 3, 5, 7, 9, 11, 3, 5, 7, 9, 11, 3, 3, 5, 3, 5, 7, 9, 11, 3, 3, 5, 7, 9, 11, 3, 5, 7, 9, 11, 3, 3, 5, 7, 9, 11, 13, 3, 5, 7, 9, 11, 13, 3, 3, 5, 7, 3, 5, 3, 3, 5, 7, 9, 11, 3, 5, 7, 9, 11, 13, 3, 3, 5, 3, 5, 7, 3, 3, 5, 7, 9, 11, 13, 3, 5, 7, 9, 11, 13, 3, 3, 5, 7, 9, 11, 13, 3, 5, 7, 9, 11, 13, 3, 3, 5, 7, 9, 11, 13, 3, 5, 3, 3, 5, 7, 9, 11, 13, 3, 5, 7, 9, 11, 13, 3, 3, 5, 3, 5, 7, 9, 11, 13, 3, 3, 5, 7, 9, 11, 13, 3, 5, 7, 9, 11, 3, 3, 
# ...

# %%
# %timeit collect(20000)
# Out:
# 1.27 s ± 41.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %lprun -f prime collect(20000)

# %% [markdown]
# ## Version-01

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %lprun -f prime prime(134567)

# %% [markdown]
# ## Version-02

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
r = collect(1200000)

# %%
# %lprun -f prime collect(20000)

# %%
# %prun collect(1200000)

# %%
# %lprun -f prime prime(134567)

# %% [markdown]
# ## 第三个版本

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
collect(134567)
# Out:
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11,
# 11, 13,
# 11, 13,
# 11,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11, 13,
# 11,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11, 13, 15,
# 11,
# 11, 13, 15,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17,
# 11, 13, 15, 17, 19,
# 11, 13,
# 11,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# 11, 13, 15, 17, 19,
# ...

# %%
# %lprun -f prime collect(20000)

# %%
import pandas
# Out:
# /Users/gaominquan/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
file_path = "/Users/gaominquan/Workspace/jupyters_and_slides/2020-spring/sqlResult_1558435.csv"

# %%
df = pandas.read_csv(file_path, encoding='gb18030')

# %%
df
# Out:
#           id      author                  source  \
# 0      89617         NaN  快科技@http://www.kkj.cn/
# 1      89616         NaN  快科技@http://www.kkj.cn/
# 2      89615         NaN  快科技@http://www.kkj.cn/
# 3      89614         NaN                     新华社
# 4      89613  胡淑丽_MN7479                   深圳大件事
# ...      ...         ...                     ...
# 89606      5          邹峥                     新华社
# 89607      4          王衡                     新华社
# 89608      3          张旌                     新华社
# 89609      2         夏文辉                     新华社
# 89610      1      王子江 张寒                     新华社
#
#                                                  content  \
# 0      此外，自本周（6月12日）起，除小米手机6等15款机型外，其余机型已暂停更新发布（含开发版/...
# 1      骁龙835作为唯一通过Windows 10桌面平台认证的ARM处理器，高通强调，不会因为只考...
# 2      此前的一加3T搭载的是3400mAh电池，DashCharge快充规格为5V/4A。\r\n...
# 3        这是6月18日在葡萄牙中部大佩德罗冈地区拍摄的被森林大火烧毁的汽车。新华社记者张立云摄\r\n
# 4      （原标题：44岁女子跑深圳约会网友被拒，暴雨中裸身奔走……）\r\n@深圳交警微博称：昨日清...
# ...

# %% [markdown]
# "包含了这个关键字，需要高亮" -> "包含了这个#关键字#，需要高亮"

# %%
import re

# %%
help(re.sub)
# Out:
# Help on function sub in module re:
#
# sub(pattern, repl, string, count=0, flags=0)
#     Return the string obtained by replacing the leftmost
#     non-overlapping occurrences of the pattern in string by the
#     replacement repl.  repl can be either a string or a callable;
#     if a string, backslash escapes in it are processed.  If it is
#     a callable, it's passed the Match object and must return
#     a replacement string to be used.

# %%
def sub_pat(keyword, string):
    return re.sub(r'({})'.format(keyword), r'#\g<1>#', string)

# %%
sub_pat('关键字', '包含了这个关键字，需要高亮')
# Out:
# '包含了这个#关键字#，需要高亮'

# %%
# !pip install memory_profiler
# Out:
# Looking in indexes: https://pypi.douban.com/simple
# ...
#   Stored in directory: /Users/gaominquan/Library/Caches/pip/wheels/46/87/b4/9e7d212ef44e4502dbddbede48253c2c07c0d9de87a4e04a0e
# Successfully built memory-profiler
# ...

# %%
# %load_ext memory_profiler

# %%
# %%file mprun_example.py
def search(keyword, dataframe, topn=1000):
    all_string = ""
    
    for row in dataframe['content'][:topn]:
        all_string += str(row)
    
    return sub_pat(keyword, all_string)
# Out:
# Overwriting mprun_example.py

# %%
# %memit r = search('手机', df)
# Out:
# peak memory: 134.75 MiB, increment: 1.11 MiB

# %%
from profiler_show import search_keyword
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-238-64cb1db97335> in <module>
# ----> 1 from profiler_show import search_keyword
#
# ModuleNotFoundError: No module named 'profiler_show'

# %%
# %mprun -f search search('手机', df)
# Out:
# ERROR: Could not find file <ipython-input-215-98e03dc121dd>
# NOTE: %mprun can only be used on functions defined in physical files, and not in the IPython environment.
